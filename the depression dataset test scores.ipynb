# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
scores =  pd.read_csv('/kaggle/input/the-depression-dataset/data/scores.csv')
scores
# Out:
#           number  days  gender    age  afftype  melanch  inpatient    edu  \
# 0    condition_1    11       2  35-39      2.0      2.0        2.0   6-10
# 1    condition_2    18       2  40-44      1.0      2.0        2.0   6-10
# 2    condition_3    13       1  45-49      2.0      2.0        2.0   6-10
# 3    condition_4    13       2  25-29      2.0      2.0        2.0  11-15
# 4    condition_5    13       2  50-54      2.0      2.0        2.0  11-15
# 5    condition_6     7       1  35-39      2.0      2.0        2.0   6-10
# 6    condition_7    11       1  20-24      1.0      NaN        2.0  11-15
# 7    condition_8     5       2  25-29      2.0      NaN        2.0  11-15
# 8    condition_9    13       2  45-49      1.0      NaN        2.0   6-10
# 9   condition_10     9       2  45-49      2.0      2.0        2.0   6-10
# 10  condition_11    14       1  45-49      2.0      2.0        2.0   6-10
# 11  condition_12    12       2  40-44      1.0      2.0        2.0   6-10
# 12  condition_13    14       2  35-39      1.0      2.0        2.0  11-15
# 13  condition_14    14       1  60-64      1.0      2.0        2.0   6-10
# 14  condition_15    13       2  55-59      2.0      2.0        2.0  11-15
# 15  condition_16    16       1  45-49      2.0      2.0        2.0  11-15
# 16  condition_17    13       1  50-54      1.0      2.0        2.0   6-10
# 17  condition_18    13       2  40-44      3.0      2.0        2.0  11-15
# 18  condition_19    13       2  50-54      2.0      2.0        1.0  16-20
# 19  condition_20    13       1  30-34      2.0      1.0        1.0   6-10
# 20  condition_21    13       2  35-39      2.0      2.0        1.0   6-10
# 21  condition_22    14       1  65-69      2.0      2.0        1.0
# 22  condition_23    16       1  30-34      2.0      2.0        1.0  16-20
# 23     control_1     8       2  25-29      NaN      NaN        NaN    NaN
# 24     control_2    20       1  30-34      NaN      NaN        NaN
# 25     control_3    12       2  30-34      NaN      NaN        NaN
# 26     control_4    13       1  25-29      NaN      NaN        NaN
# 27     control_5    13       1  30-34      NaN      NaN        NaN
# 28     control_6    13       1  25-29      NaN      NaN        NaN
# 29     control_7    13       1  20-24      NaN      NaN        NaN
# 30     control_8    13       2  40-44      NaN      NaN        NaN
# 31     control_9    13       2  30-34      NaN      NaN        NaN
# 32    control_10     8       1  30-34      NaN      NaN        NaN
# 33    control_11    13       1  45-49      NaN      NaN        NaN
# 34    control_12    14       1  60-64      NaN      NaN        NaN
# 35    control_13    13       1  50-54      NaN      NaN        NaN    NaN
# 36    control_14    13       1  50-54      NaN      NaN        NaN
# 37    control_15    11       1  45-49      NaN      NaN        NaN
# 38    control_16    13       2  40-44      NaN      NaN        NaN
# 39    control_17     9       1  45-49      NaN      NaN        NaN
# 40    control_18    13       2  20-24      NaN      NaN        NaN
# 41    control_19    13       1  50-54      NaN      NaN        NaN
# 42    control_20    13       1  35-39      NaN      NaN        NaN
# 43    control_21     8       1  50-54      NaN      NaN        NaN
# 44    control_22    13       1  25-29      NaN      NaN        NaN
# 45    control_23    13       1  20-24      NaN      NaN        NaN
# 46    control_24    13       2  20-24      NaN      NaN        NaN
# 47    control_25    13       1  65-69      NaN      NaN        NaN
# 48    control_26    13       1  35-39      NaN      NaN        NaN
# 49    control_27    13       2  50-54      NaN      NaN        NaN
# 50    control_28    16       2  45-49      NaN      NaN        NaN
# 51    control_29    13       2  50-54      NaN      NaN        NaN
# 52    control_30     9       2  35-39      NaN      NaN        NaN
# 53    control_31    13       1  20-24      NaN      NaN        NaN
# 54    control_32    14       2  25-29      NaN      NaN        NaN
#
#     marriage  work  madrs1  madrs2
# 0        1.0   2.0    19.0    19.0
# 1        2.0   2.0    24.0    11.0
# 2        2.0   2.0    24.0    25.0
# 3        1.0   1.0    20.0    16.0
# 4        2.0   2.0    26.0    26.0
# 5        1.0   2.0    18.0    15.0
# 6        2.0   1.0    24.0    25.0
# 7        1.0   2.0    20.0    16.0
# 8        1.0   2.0    26.0    26.0
# 9        1.0   2.0    28.0    21.0
# 10       1.0   2.0    24.0    24.0
# 11       2.0   2.0    25.0    21.0
# 12       2.0   2.0    18.0    13.0
# 13       2.0   2.0    28.0    19.0
# 14       1.0   1.0    14.0    18.0
# 15       1.0   2.0    13.0    17.0
# 16       1.0   2.0    17.0    15.0
# 17       2.0   2.0    18.0    15.0
# 18       2.0   2.0    26.0    21.0
# 19       1.0   2.0    27.0    25.0
# 20       2.0   2.0    26.0    21.0
# 21       2.0   2.0    29.0    28.0
# 22       2.0   2.0    29.0    23.0
# 23       NaN   NaN     NaN     NaN
# 24       NaN   NaN     NaN     NaN
# 25       NaN   NaN     NaN     NaN
# 26       NaN   NaN     NaN     NaN
# 27       NaN   NaN     NaN     NaN
# 28       NaN   NaN     NaN     NaN
# 29       NaN   NaN     NaN     NaN
# 30       NaN   NaN     NaN     NaN
# 31       NaN   NaN     NaN     NaN
# 32       NaN   NaN     NaN     NaN
# 33       NaN   NaN     NaN     NaN
# 34       NaN   NaN     NaN     NaN
# 35       NaN   NaN     NaN     NaN
# 36       NaN   NaN     NaN     NaN
# 37       NaN   NaN     NaN     NaN
# 38       NaN   NaN     NaN     NaN
# 39       NaN   NaN     NaN     NaN
# 40       NaN   NaN     NaN     NaN
# 41       NaN   NaN     NaN     NaN
# 42       NaN   NaN     NaN     NaN
# 43       NaN   NaN     NaN     NaN
# 44       NaN   NaN     NaN     NaN
# 45       NaN   NaN     NaN     NaN
# 46       NaN   NaN     NaN     NaN
# 47       NaN   NaN     NaN     NaN
# 48       NaN   NaN     NaN     NaN
# 49       NaN   NaN     NaN     NaN
# 50       NaN   NaN     NaN     NaN
# 51       NaN   NaN     NaN     NaN
# 52       NaN   NaN     NaN     NaN
# 53       NaN   NaN     NaN     NaN
# 54       NaN   NaN     NaN     NaN

# %%
scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   number     55 non-null     object
#  1   days       55 non-null     int64
#  2   gender     55 non-null     int64
#  3   age        55 non-null     object
#  4   afftype    23 non-null     float64
#  5   melanch    20 non-null     float64
#  6   inpatient  23 non-null     float64
#  7   edu        53 non-null     object
#  8   marriage   23 non-null     float64
#  9   work       23 non-null     float64
#  10  madrs1     23 non-null     float64
#  11  madrs2     23 non-null     float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 5.3+ KB

# %%
scores['DeltaMADRS'] = scores.madrs2 - scores.madrs1
scores.head()
# Out:
#         number  days  gender    age  afftype  melanch  inpatient    edu  \
# 0  condition_1    11       2  35-39      2.0      2.0        2.0   6-10
# 1  condition_2    18       2  40-44      1.0      2.0        2.0   6-10
# 2  condition_3    13       1  45-49      2.0      2.0        2.0   6-10
# 3  condition_4    13       2  25-29      2.0      2.0        2.0  11-15
# 4  condition_5    13       2  50-54      2.0      2.0        2.0  11-15
#
#    marriage  work  madrs1  madrs2  DeltaMADRS
# 0       1.0   2.0    19.0    19.0         0.0
# 1       2.0   2.0    24.0    11.0       -13.0
# 2       2.0   2.0    24.0    25.0         1.0
# 3       1.0   1.0    20.0    16.0        -4.0
# 4       2.0   2.0    26.0    26.0         0.0

# %%
scores.edu = scores['edu'].replace(' ', np.NaN)
scores
# Out:
#           number  days  gender    age  afftype  melanch  inpatient    edu  \
# 0    condition_1    11       2  35-39      2.0      2.0        2.0   6-10
# 1    condition_2    18       2  40-44      1.0      2.0        2.0   6-10
# 2    condition_3    13       1  45-49      2.0      2.0        2.0   6-10
# 3    condition_4    13       2  25-29      2.0      2.0        2.0  11-15
# 4    condition_5    13       2  50-54      2.0      2.0        2.0  11-15
# 5    condition_6     7       1  35-39      2.0      2.0        2.0   6-10
# 6    condition_7    11       1  20-24      1.0      NaN        2.0  11-15
# 7    condition_8     5       2  25-29      2.0      NaN        2.0  11-15
# 8    condition_9    13       2  45-49      1.0      NaN        2.0   6-10
# 9   condition_10     9       2  45-49      2.0      2.0        2.0   6-10
# 10  condition_11    14       1  45-49      2.0      2.0        2.0   6-10
# 11  condition_12    12       2  40-44      1.0      2.0        2.0   6-10
# 12  condition_13    14       2  35-39      1.0      2.0        2.0  11-15
# 13  condition_14    14       1  60-64      1.0      2.0        2.0   6-10
# 14  condition_15    13       2  55-59      2.0      2.0        2.0  11-15
# 15  condition_16    16       1  45-49      2.0      2.0        2.0  11-15
# 16  condition_17    13       1  50-54      1.0      2.0        2.0   6-10
# 17  condition_18    13       2  40-44      3.0      2.0        2.0  11-15
# 18  condition_19    13       2  50-54      2.0      2.0        1.0  16-20
# 19  condition_20    13       1  30-34      2.0      1.0        1.0   6-10
# 20  condition_21    13       2  35-39      2.0      2.0        1.0   6-10
# 21  condition_22    14       1  65-69      2.0      2.0        1.0    NaN
# 22  condition_23    16       1  30-34      2.0      2.0        1.0  16-20
# 23     control_1     8       2  25-29      NaN      NaN        NaN    NaN
# 24     control_2    20       1  30-34      NaN      NaN        NaN    NaN
# 25     control_3    12       2  30-34      NaN      NaN        NaN    NaN
# 26     control_4    13       1  25-29      NaN      NaN        NaN    NaN
# 27     control_5    13       1  30-34      NaN      NaN        NaN    NaN
# 28     control_6    13       1  25-29      NaN      NaN        NaN    NaN
# 29     control_7    13       1  20-24      NaN      NaN        NaN    NaN
# 30     control_8    13       2  40-44      NaN      NaN        NaN    NaN
# 31     control_9    13       2  30-34      NaN      NaN        NaN    NaN
# 32    control_10     8       1  30-34      NaN      NaN        NaN    NaN
# 33    control_11    13       1  45-49      NaN      NaN        NaN    NaN
# 34    control_12    14       1  60-64      NaN      NaN        NaN    NaN
# 35    control_13    13       1  50-54      NaN      NaN        NaN    NaN
# 36    control_14    13       1  50-54      NaN      NaN        NaN    NaN
# 37    control_15    11       1  45-49      NaN      NaN        NaN    NaN
# 38    control_16    13       2  40-44      NaN      NaN        NaN    NaN
# 39    control_17     9       1  45-49      NaN      NaN        NaN    NaN
# 40    control_18    13       2  20-24      NaN      NaN        NaN    NaN
# 41    control_19    13       1  50-54      NaN      NaN        NaN    NaN
# 42    control_20    13       1  35-39      NaN      NaN        NaN    NaN
# 43    control_21     8       1  50-54      NaN      NaN        NaN    NaN
# 44    control_22    13       1  25-29      NaN      NaN        NaN    NaN
# 45    control_23    13       1  20-24      NaN      NaN        NaN    NaN
# 46    control_24    13       2  20-24      NaN      NaN        NaN    NaN
# 47    control_25    13       1  65-69      NaN      NaN        NaN    NaN
# 48    control_26    13       1  35-39      NaN      NaN        NaN    NaN
# 49    control_27    13       2  50-54      NaN      NaN        NaN    NaN
# 50    control_28    16       2  45-49      NaN      NaN        NaN    NaN
# 51    control_29    13       2  50-54      NaN      NaN        NaN    NaN
# 52    control_30     9       2  35-39      NaN      NaN        NaN    NaN
# 53    control_31    13       1  20-24      NaN      NaN        NaN    NaN
# 54    control_32    14       2  25-29      NaN      NaN        NaN    NaN
#
#     marriage  work  madrs1  madrs2  DeltaMADRS
# 0        1.0   2.0    19.0    19.0         0.0
# 1        2.0   2.0    24.0    11.0       -13.0
# 2        2.0   2.0    24.0    25.0         1.0
# 3        1.0   1.0    20.0    16.0        -4.0
# 4        2.0   2.0    26.0    26.0         0.0
# 5        1.0   2.0    18.0    15.0        -3.0
# 6        2.0   1.0    24.0    25.0         1.0
# 7        1.0   2.0    20.0    16.0        -4.0
# 8        1.0   2.0    26.0    26.0         0.0
# 9        1.0   2.0    28.0    21.0        -7.0
# 10       1.0   2.0    24.0    24.0         0.0
# 11       2.0   2.0    25.0    21.0        -4.0
# 12       2.0   2.0    18.0    13.0        -5.0
# 13       2.0   2.0    28.0    19.0        -9.0
# 14       1.0   1.0    14.0    18.0         4.0
# 15       1.0   2.0    13.0    17.0         4.0
# 16       1.0   2.0    17.0    15.0        -2.0
# 17       2.0   2.0    18.0    15.0        -3.0
# 18       2.0   2.0    26.0    21.0        -5.0
# 19       1.0   2.0    27.0    25.0        -2.0
# 20       2.0   2.0    26.0    21.0        -5.0
# 21       2.0   2.0    29.0    28.0        -1.0
# 22       2.0   2.0    29.0    23.0        -6.0
# 23       NaN   NaN     NaN     NaN         NaN
# 24       NaN   NaN     NaN     NaN         NaN
# 25       NaN   NaN     NaN     NaN         NaN
# 26       NaN   NaN     NaN     NaN         NaN
# 27       NaN   NaN     NaN     NaN         NaN
# 28       NaN   NaN     NaN     NaN         NaN
# 29       NaN   NaN     NaN     NaN         NaN
# 30       NaN   NaN     NaN     NaN         NaN
# 31       NaN   NaN     NaN     NaN         NaN
# 32       NaN   NaN     NaN     NaN         NaN
# 33       NaN   NaN     NaN     NaN         NaN
# 34       NaN   NaN     NaN     NaN         NaN
# 35       NaN   NaN     NaN     NaN         NaN
# 36       NaN   NaN     NaN     NaN         NaN
# 37       NaN   NaN     NaN     NaN         NaN
# 38       NaN   NaN     NaN     NaN         NaN
# 39       NaN   NaN     NaN     NaN         NaN
# 40       NaN   NaN     NaN     NaN         NaN
# 41       NaN   NaN     NaN     NaN         NaN
# 42       NaN   NaN     NaN     NaN         NaN
# 43       NaN   NaN     NaN     NaN         NaN
# 44       NaN   NaN     NaN     NaN         NaN
# 45       NaN   NaN     NaN     NaN         NaN
# 46       NaN   NaN     NaN     NaN         NaN
# 47       NaN   NaN     NaN     NaN         NaN
# 48       NaN   NaN     NaN     NaN         NaN
# 49       NaN   NaN     NaN     NaN         NaN
# 50       NaN   NaN     NaN     NaN         NaN
# 51       NaN   NaN     NaN     NaN         NaN
# 52       NaN   NaN     NaN     NaN         NaN
# 53       NaN   NaN     NaN     NaN         NaN
# 54       NaN   NaN     NaN     NaN         NaN

# %%
scores.age = scores.age.astype('category')
scores.gender = scores.gender.astype('category')
scores.edu = scores.edu.astype('category')
scores.afftype = scores.afftype.astype('category')
scores.melanch = scores.melanch.astype('category')
scores.inpatient = scores.inpatient.astype('category')
scores.marriage = scores.marriage.astype('category')
scores.work = scores.work.astype('category')
scores.head()
# Out:
#         number  days gender    age afftype melanch inpatient    edu marriage  \
# 0  condition_1    11      2  35-39     2.0     2.0       2.0   6-10      1.0
# 1  condition_2    18      2  40-44     1.0     2.0       2.0   6-10      2.0
# 2  condition_3    13      1  45-49     2.0     2.0       2.0   6-10      2.0
# 3  condition_4    13      2  25-29     2.0     2.0       2.0  11-15      1.0
# 4  condition_5    13      2  50-54     2.0     2.0       2.0  11-15      2.0
#
#   work  madrs1  madrs2  DeltaMADRS
# 0  2.0    19.0    19.0         0.0
# 1  2.0    24.0    11.0       -13.0
# 2  2.0    24.0    25.0         1.0
# 3  1.0    20.0    16.0        -4.0
# 4  2.0    26.0    26.0         0.0

# %%
scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   number      55 non-null     object
#  1   days        55 non-null     int64
#  2   gender      55 non-null     category
#  3   age         55 non-null     category
#  4   afftype     23 non-null     category
#  5   melanch     20 non-null     category
#  6   inpatient   23 non-null     category
#  7   edu         22 non-null     category
#  8   marriage    23 non-null     category
#  9   work        23 non-null     category
#  10  madrs1      23 non-null     float64
#  11  madrs2      23 non-null     float64
#  12  DeltaMADRS  23 non-null     float64
# dtypes: category(8), float64(3), int64(1), object(1)
# memory usage: 3.9+ KB

# %%
scores.gender = scores['gender'].cat.rename_categories({1.0 : 'female',2.0:'male'})
scores.afftype = scores['afftype'].cat.rename_categories({1.0 : 'bipolar II',2.0:'unipolar', 3: 'bipolar I'})
scores.melanch = scores['melanch'].cat.rename_categories({1.0 : 'melancholia',2.0:'No melancholia'})
scores.inpatient = scores['inpatient'].cat.rename_categories({1.0 : 'inpatient',2.0:'outpatient'})
scores.marriage = scores['marriage'].cat.rename_categories({1.0 : 'married/cohabitating',2.0:'single'})
scores.work = scores['work'].cat.rename_categories({1.0 : 'Work/Study',2.0:'Unemployed/Sick leave/Pension'})
scores
# Out:
#           number  days  gender    age     afftype         melanch   inpatient  \
# 0    condition_1    11    male  35-39    unipolar  No melancholia  outpatient
# 1    condition_2    18    male  40-44  bipolar II  No melancholia  outpatient
# 2    condition_3    13  female  45-49    unipolar  No melancholia  outpatient
# 3    condition_4    13    male  25-29    unipolar  No melancholia  outpatient
# 4    condition_5    13    male  50-54    unipolar  No melancholia  outpatient
# 5    condition_6     7  female  35-39    unipolar  No melancholia  outpatient
# 6    condition_7    11  female  20-24  bipolar II             NaN  outpatient
# 7    condition_8     5    male  25-29    unipolar             NaN  outpatient
# 8    condition_9    13    male  45-49  bipolar II             NaN  outpatient
# 9   condition_10     9    male  45-49    unipolar  No melancholia  outpatient
# 10  condition_11    14  female  45-49    unipolar  No melancholia  outpatient
# 11  condition_12    12    male  40-44  bipolar II  No melancholia  outpatient
# 12  condition_13    14    male  35-39  bipolar II  No melancholia  outpatient
# 13  condition_14    14  female  60-64  bipolar II  No melancholia  outpatient
# 14  condition_15    13    male  55-59    unipolar  No melancholia  outpatient
# 15  condition_16    16  female  45-49    unipolar  No melancholia  outpatient
# 16  condition_17    13  female  50-54  bipolar II  No melancholia  outpatient
# 17  condition_18    13    male  40-44   bipolar I  No melancholia  outpatient
# 18  condition_19    13    male  50-54    unipolar  No melancholia   inpatient
# 19  condition_20    13  female  30-34    unipolar     melancholia   inpatient
# 20  condition_21    13    male  35-39    unipolar  No melancholia   inpatient
# 21  condition_22    14  female  65-69    unipolar  No melancholia   inpatient
# 22  condition_23    16  female  30-34    unipolar  No melancholia   inpatient
# 23     control_1     8    male  25-29         NaN             NaN         NaN
# 24     control_2    20  female  30-34         NaN             NaN         NaN
# 25     control_3    12    male  30-34         NaN             NaN         NaN
# 26     control_4    13  female  25-29         NaN             NaN         NaN
# 27     control_5    13  female  30-34         NaN             NaN         NaN
# 28     control_6    13  female  25-29         NaN             NaN         NaN
# 29     control_7    13  female  20-24         NaN             NaN         NaN
# 30     control_8    13    male  40-44         NaN             NaN         NaN
# 31     control_9    13    male  30-34         NaN             NaN         NaN
# 32    control_10     8  female  30-34         NaN             NaN         NaN
# 33    control_11    13  female  45-49         NaN             NaN         NaN
# 34    control_12    14  female  60-64         NaN             NaN         NaN
# 35    control_13    13  female  50-54         NaN             NaN         NaN
# 36    control_14    13  female  50-54         NaN             NaN         NaN
# 37    control_15    11  female  45-49         NaN             NaN         NaN
# 38    control_16    13    male  40-44         NaN             NaN         NaN
# 39    control_17     9  female  45-49         NaN             NaN         NaN
# 40    control_18    13    male  20-24         NaN             NaN         NaN
# 41    control_19    13  female  50-54         NaN             NaN         NaN
# 42    control_20    13  female  35-39         NaN             NaN         NaN
# 43    control_21     8  female  50-54         NaN             NaN         NaN
# 44    control_22    13  female  25-29         NaN             NaN         NaN
# 45    control_23    13  female  20-24         NaN             NaN         NaN
# 46    control_24    13    male  20-24         NaN             NaN         NaN
# 47    control_25    13  female  65-69         NaN             NaN         NaN
# 48    control_26    13  female  35-39         NaN             NaN         NaN
# 49    control_27    13    male  50-54         NaN             NaN         NaN
# 50    control_28    16    male  45-49         NaN             NaN         NaN
# 51    control_29    13    male  50-54         NaN             NaN         NaN
# 52    control_30     9    male  35-39         NaN             NaN         NaN
# 53    control_31    13  female  20-24         NaN             NaN         NaN
# 54    control_32    14    male  25-29         NaN             NaN         NaN
#
#       edu              marriage                           work  madrs1  \
# 0    6-10  married/cohabitating  Unemployed/Sick leave/Pension    19.0
# 1    6-10                single  Unemployed/Sick leave/Pension    24.0
# 2    6-10                single  Unemployed/Sick leave/Pension    24.0
# 3   11-15  married/cohabitating                     Work/Study    20.0
# 4   11-15                single  Unemployed/Sick leave/Pension    26.0
# 5    6-10  married/cohabitating  Unemployed/Sick leave/Pension    18.0
# 6   11-15                single                     Work/Study    24.0
# 7   11-15  married/cohabitating  Unemployed/Sick leave/Pension    20.0
# 8    6-10  married/cohabitating  Unemployed/Sick leave/Pension    26.0
# 9    6-10  married/cohabitating  Unemployed/Sick leave/Pension    28.0
# 10   6-10  married/cohabitating  Unemployed/Sick leave/Pension    24.0
# 11   6-10                single  Unemployed/Sick leave/Pension    25.0
# 12  11-15                single  Unemployed/Sick leave/Pension    18.0
# 13   6-10                single  Unemployed/Sick leave/Pension    28.0
# 14  11-15  married/cohabitating                     Work/Study    14.0
# 15  11-15  married/cohabitating  Unemployed/Sick leave/Pension    13.0
# 16   6-10  married/cohabitating  Unemployed/Sick leave/Pension    17.0
# 17  11-15                single  Unemployed/Sick leave/Pension    18.0
# 18  16-20                single  Unemployed/Sick leave/Pension    26.0
# 19   6-10  married/cohabitating  Unemployed/Sick leave/Pension    27.0
# 20   6-10                single  Unemployed/Sick leave/Pension    26.0
# 21    NaN                single  Unemployed/Sick leave/Pension    29.0
# 22  16-20                single  Unemployed/Sick leave/Pension    29.0
# 23    NaN                   NaN                            NaN     NaN
# 24    NaN                   NaN                            NaN     NaN
# 25    NaN                   NaN                            NaN     NaN
# 26    NaN                   NaN                            NaN     NaN
# 27    NaN                   NaN                            NaN     NaN
# 28    NaN                   NaN                            NaN     NaN
# 29    NaN                   NaN                            NaN     NaN
# 30    NaN                   NaN                            NaN     NaN
# 31    NaN                   NaN                            NaN     NaN
# 32    NaN                   NaN                            NaN     NaN
# 33    NaN                   NaN                            NaN     NaN
# 34    NaN                   NaN                            NaN     NaN
# 35    NaN                   NaN                            NaN     NaN
# 36    NaN                   NaN                            NaN     NaN
# 37    NaN                   NaN                            NaN     NaN
# 38    NaN                   NaN                            NaN     NaN
# 39    NaN                   NaN                            NaN     NaN
# 40    NaN                   NaN                            NaN     NaN
# 41    NaN                   NaN                            NaN     NaN
# 42    NaN                   NaN                            NaN     NaN
# 43    NaN                   NaN                            NaN     NaN
# 44    NaN                   NaN                            NaN     NaN
# 45    NaN                   NaN                            NaN     NaN
# 46    NaN                   NaN                            NaN     NaN
# 47    NaN                   NaN                            NaN     NaN
# 48    NaN                   NaN                            NaN     NaN
# 49    NaN                   NaN                            NaN     NaN
# 50    NaN                   NaN                            NaN     NaN
# 51    NaN                   NaN                            NaN     NaN
# 52    NaN                   NaN                            NaN     NaN
# 53    NaN                   NaN                            NaN     NaN
# 54    NaN                   NaN                            NaN     NaN
#
#     madrs2  DeltaMADRS
# 0     19.0         0.0
# 1     11.0       -13.0
# 2     25.0         1.0
# 3     16.0        -4.0
# 4     26.0         0.0
# 5     15.0        -3.0
# 6     25.0         1.0
# 7     16.0        -4.0
# 8     26.0         0.0
# 9     21.0        -7.0
# 10    24.0         0.0
# 11    21.0        -4.0
# 12    13.0        -5.0
# 13    19.0        -9.0
# 14    18.0         4.0
# 15    17.0         4.0
# 16    15.0        -2.0
# 17    15.0        -3.0
# 18    21.0        -5.0
# 19    25.0        -2.0
# 20    21.0        -5.0
# 21    28.0        -1.0
# 22    23.0        -6.0
# 23     NaN         NaN
# 24     NaN         NaN
# 25     NaN         NaN
# 26     NaN         NaN
# 27     NaN         NaN
# 28     NaN         NaN
# 29     NaN         NaN
# 30     NaN         NaN
# 31     NaN         NaN
# 32     NaN         NaN
# 33     NaN         NaN
# 34     NaN         NaN
# 35     NaN         NaN
# 36     NaN         NaN
# 37     NaN         NaN
# 38     NaN         NaN
# 39     NaN         NaN
# 40     NaN         NaN
# 41     NaN         NaN
# 42     NaN         NaN
# 43     NaN         NaN
# 44     NaN         NaN
# 45     NaN         NaN
# 46     NaN         NaN
# 47     NaN         NaN
# 48     NaN         NaN
# 49     NaN         NaN
# 50     NaN         NaN
# 51     NaN         NaN
# 52     NaN         NaN
# 53     NaN         NaN
# 54     NaN         NaN

# %%
scores_condition = scores[scores.number.str.contains('condition')].copy()
scores_condition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 0 to 22
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   number      23 non-null     object
#  1   days        23 non-null     int64
#  2   gender      23 non-null     category
#  3   age         23 non-null     category
#  4   afftype     23 non-null     category
#  5   melanch     20 non-null     category
#  6   inpatient   23 non-null     category
#  7   edu         22 non-null     category
#  8   marriage    23 non-null     category
#  9   work        23 non-null     category
#  10  madrs1      23 non-null     float64
#  11  madrs2      23 non-null     float64
#  12  DeltaMADRS  23 non-null     float64
# dtypes: category(8), float64(3), int64(1), object(1)
# memory usage: 2.5+ KB

# %%
scores_control = scores[scores.number.str.contains('control')].copy()
scores_control.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 23 to 54
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   number      32 non-null     object
#  1   days        32 non-null     int64
#  2   gender      32 non-null     category
#  3   age         32 non-null     category
#  4   afftype     0 non-null      category
#  5   melanch     0 non-null      category
#  6   inpatient   0 non-null      category
#  7   edu         0 non-null      category
#  8   marriage    0 non-null      category
#  9   work        0 non-null      category
#  10  madrs1      0 non-null      float64
#  11  madrs2      0 non-null      float64
#  12  DeltaMADRS  0 non-null      float64
# dtypes: category(8), float64(3), int64(1), object(1)
# memory usage: 3.0+ KB

# %%
features_num = ['days','madrs1','madrs2','DeltaMADRS']
features_cat = ['age', 'gender', 'afftype', 'melanch', 'inpatient', 'edu', 'marriage', 'work']

# %% [markdown]
# MADRS interpretation
#
# - 0 to 6: normal range (no depression),
# - 7 to 19 : mild depression
# - 20 to 34: moderate depression
# - 35 and greater: severe depression
# - 60 or greater: “very severe depression

# %%
# barplot of MADRS scores (before/after)
temp_plot_paras = plt.rcParams['figure.figsize']

plt.rcParams['figure.figsize'] = (14,4)
scores_condition.plot(x='number', y=['madrs1','madrs2'], kind='bar')
plt.title('MADRS Development')
plt.grid()
plt.show()

plt.rcParams['figure.figsize'] = temp_plot_paras

# %%
for f in features_num:
    scores_condition[f].plot(kind='hist')
    plt.title(f)
    plt.grid()
    plt.show()

# %%
for f in features_cat:
    scores_condition[f].value_counts().sort_index().plot(kind='bar')
    plt.title(f)
    plt.grid()
    plt.show()

# %%
# impact of feature on score madrs1 (at begin of activity measurement)
for f in features_cat:
    plt.figure(figsize=(10,4))
    sns.violinplot(data=scores_condition, x=f, y='madrs1')
    plt.title('madrs1 vs ' + f)
    plt.grid()
    plt.show()

# %%
# impact of feature on score madrs1 (at begin of activity measurement)
for f in features_cat:
    plt.figure(figsize=(10,4))
    sns.violinplot(data=scores_condition, x=f, y='madrs2')
    plt.title('madrs2 vs ' + f)
    plt.grid()
    plt.show()

# %%
# impact of feature on score difference DeltaMADRS = madrs2 - madrs1
for f in features_cat:
    plt.figure(figsize=(10,4))
    sns.violinplot(data=scores_condition, x=f, y='DeltaMADRS')
    plt.title('DeltaMADRS vs ' + f)
    plt.grid()
    plt.show()

# %% [markdown]
# ## Activity Data Analysis

# %%
control_1 = pd.read_csv('/kaggle/input/the-depression-dataset/data/control/control_1.csv')
condition_1 = pd.read_csv('/kaggle/input/the-depression-dataset/data/condition/condition_1.csv')
print(f'control_1.shape: {control_1.shape}')
print(f'condition_1.shape: {condition_1.shape}')
# Out:
# control_1.shape: (51611, 3)
# condition_1.shape: (23244, 3)

# %%
control_1.head()
# Out:
#              timestamp        date  activity
# 0  2003-03-18 15:00:00  2003-03-18        60
# 1  2003-03-18 15:01:00  2003-03-18         0
# 2  2003-03-18 15:02:00  2003-03-18       264
# 3  2003-03-18 15:03:00  2003-03-18       662
# 4  2003-03-18 15:04:00  2003-03-18       293

# %%
condition_1.head()
# Out:
#              timestamp        date  activity
# 0  2003-05-07 12:00:00  2003-05-07         0
# 1  2003-05-07 12:01:00  2003-05-07       143
# 2  2003-05-07 12:02:00  2003-05-07         0
# 3  2003-05-07 12:03:00  2003-05-07        20
# 4  2003-05-07 12:04:00  2003-05-07       166

# %%
condition_1.timestamp = condition_1.timestamp.str.split(' ', expand=True)[[1]]
condition_1
# Out:
#       timestamp        date  activity
# 0      12:00:00  2003-05-07         0
# 1      12:01:00  2003-05-07       143
# 2      12:02:00  2003-05-07         0
# 3      12:03:00  2003-05-07        20
# 4      12:04:00  2003-05-07       166
# ...         ...         ...       ...
# 23239  15:19:00  2003-05-23         0
# 23240  15:20:00  2003-05-23         0
# 23241  15:21:00  2003-05-23         0
# 23242  15:22:00  2003-05-23         0
# 23243  15:23:00  2003-05-23       533
#
# [23244 rows x 3 columns]

# %%
#hourly:
condition_1['hour'] = condition_1.timestamp.str.split(':', expand=True)[[0]]
condition_1['hour']
# Out:
# 0        12
# 1        12
# 2        12
# 3        12
# 4        12
#          ..
# 23239    15
# 23240    15
# 23241    15
# 23242    15
# 23243    15
# Name: hour, Length: 23244, dtype: object

# %%
ab = condition_1.groupby(['date', 'hour'])['activity'].sum()
condition_1_aggr = pd.DataFrame(columns=('date','hour','activity'))
for i in range(0,len(ab)):
    condition_1_aggr=condition_1_aggr.append({'date':ab.index[i][0],'hour': ab.index[i][1],'activity': ab[i]},ignore_index=True)
condition_1_aggr
# Out:
#            date hour activity
# 0    2003-05-07   12    20793
# 1    2003-05-07   13    17074
# 2    2003-05-07   14    16751
# 3    2003-05-07   15    13127
# 4    2003-05-07   16    14313
# ..          ...  ...      ...
# 383  2003-05-23   11        0
# 384  2003-05-23   12        0
# 385  2003-05-23   13        0
# 386  2003-05-23   14      684
# 387  2003-05-23   15     1908
#
# [388 rows x 3 columns]

# %%
for i in condition_1_aggr.date.unique():
    plt.figure(figsize=(10,4))
    selected_data = condition_1_aggr.loc[condition_1_aggr['date'] == i]
    plt.plot(selected_data['hour'], selected_data['activity'])
    plt.title(i)
    plt.grid()
    plt.show()
